# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_restaurants = pd.read_csv('../data/df_restaurants.csv')

# %%
df_restaurants
# Out:
#        Unnamed: 0                              Name       City  \
# 0               0        Martine of Martine's Table  Amsterdam
# 1               1               De Silveren Spiegel  Amsterdam
# 2               2                           La Rive  Amsterdam
# 3               3                          Vinkeles  Amsterdam
# 4               4         Librije's Zusje Amsterdam  Amsterdam
# ...           ...                               ...        ...
# 75424      125438                              Jade     Zurich
# 75425      125444           Restaurant Moringa Teff     Zurich
# 75426      125445             Ristorante La Taverna     Zurich
# 75427      125450               not guilty Bellevue     Zurich
# 75428      125453  Hukka Restaurant & Hookah Lounge     Zurich
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                        ['French', 'Dutch', 'European']      1.0     5.0
# ...

# %%
rating_mean = df_restaurants.groupby('City').Rating.mean()
sort_rating_mean = rating_mean.sort_values(ascending=False)

# %%
sort_rating_mean = pd.DataFrame(sort_rating_mean)

# %%
sort_rating_mean
# Out:
#               Rating
# City
# Athens      4.233831
# Krakow      4.201651
# Rome        4.170070
# Oporto      4.168436
# Berlin      4.150000
# Amsterdam   4.130602
# Ljubljana   4.102167
# Budapest    4.098214
# Edinburgh   4.095541
# Bratislava  4.087699
# Hamburg     4.085938
# Dublin      4.084918
# Warsaw      4.083853
# Lisbon      4.070515
# Vienna      4.067200
# Prague      4.063735
# Munich      4.036678
# Zurich      4.036463
# Barcelona   4.023047
# Copenhagen  4.006950
# Lyon        3.993521
# Paris       3.981964
# Geneva      3.979232
# London      3.977194
# Helsinki    3.950197
# Luxembourg  3.945578
# Oslo        3.912037
# Stockholm   3.900000
# Brussels    3.899121
# Madrid      3.896003
# Milan       3.877356

# %%
top_rating_mean = sort_rating_mean.head()

# %%
top_rating_mean
# Out:
#           Rating
# City
# Athens  4.233831
# Krakow  4.201651
# Rome    4.170070
# Oporto  4.168436
# Berlin  4.150000

# %%
sns.lineplot(x=top_rating_mean.index, y = top_rating_mean.Rating, hue=top_rating_mean.index)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Rating'>

# %%
sns.boxplot(x="Price Range", y="Rating", data=df_restaurants)
# Out:
# <AxesSubplot:xlabel='Price Range', ylabel='Rating'>

# %%
sns.scatterplot(x=df_restaurants.index, y = df_restaurants.Rating, hue=top_rating_mean.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-e855ec3003ca> in <module>
# ----> 1 sns.scatterplot(x=df_restaurants.index, y = df_restaurants.Rating, hue=top_rating_mean.index)
#
# ~/.local/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/.local/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     792
#     793     variables = _ScatterPlotter.get_semantics(locals())
# --> 794     p = _ScatterPlotter(
# ...

# %%
df_pais = df_restaurants[df_restaurants.City=='Athens']

# %%
df_pais
# Out:
#       Unnamed: 0                         Name    City  \
# 2477        3434       Simul Gastronomic Situ  Athens
# 2478        3435       Cinque Wine & Deli Bar  Athens
# 2479        3436            Dinner in the Sky  Athens
# 2480        3437                       Aleria  Athens
# 2481        3438                      Feyrouz  Athens
# ...          ...                          ...     ...
# 3678        5204                     Adrianos  Athens
# 3679        5206    Union Restaurant Kolonaki  Athens
# 3680        5207  Butchers Fine Foods Stratos  Athens
# 3681        5209       Indian Paradise Kuzina  Athens
# 3682        5213                 IL Cantuccio  Athens
#
#                                           Cuisine Style  Ranking  Rating  \
# 2477  ['European', 'Vegetarian Friendly', 'Vegan Opt...      1.0     5.0
# 2478  ['Wine Bar', 'Greek', 'Delicatessen', 'Gluten ...      2.0     5.0
# 2479  ['Mediterranean', 'European', 'Greek', 'Vegeta...      3.0     5.0
# ...

# %%
sns.histplot(x=df_pais['Price Range'], hue = df_pais['Price Range'])
# Out:
# <AxesSubplot:xlabel='Price Range', ylabel='Count'>

# %%
df_restaurants
# Out:
#        Unnamed: 0                              Name       City  \
# 0               0        Martine of Martine's Table  Amsterdam
# 1               1               De Silveren Spiegel  Amsterdam
# 2               2                           La Rive  Amsterdam
# 3               3                          Vinkeles  Amsterdam
# 4               4         Librije's Zusje Amsterdam  Amsterdam
# ...           ...                               ...        ...
# 75424      125438                              Jade     Zurich
# 75425      125444           Restaurant Moringa Teff     Zurich
# 75426      125445             Ristorante La Taverna     Zurich
# 75427      125450               not guilty Bellevue     Zurich
# 75428      125453  Hukka Restaurant & Hookah Lounge     Zurich
#
#                                            Cuisine Style  Ranking  Rating  \
# 0                        ['French', 'Dutch', 'European']      1.0     5.0
# ...

# %%
df_restaurants['Cuisine Style'].unique()
# Out:
# array(["['French', 'Dutch', 'European']",
#        "['Dutch', 'European', 'Vegetarian Friendly', 'Gluten Free Options']",
#        "['Mediterranean', 'French', 'International', 'European', 'Vegetarian Friendly', 'Vegan Options']",
#        ..., "['Chinese', 'Swiss', 'Mediterranean', 'European']",
#        "['Italian', 'African', 'Ethiopian']",
#        "['German', 'Belgian', 'Mediterranean', 'European']"], dtype=object)

# %%
list(df_restaurants['Cuisine Style'].unique())
# Out:
# ["['French', 'Dutch', 'European']",
#  "['Dutch', 'European', 'Vegetarian Friendly', 'Gluten Free Options']",
#  "['Mediterranean', 'French', 'International', 'European', 'Vegetarian Friendly', 'Vegan Options']",
#  "['French', 'European', 'International', 'Contemporary', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['Dutch', 'European', 'International', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['Contemporary', 'International', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['French', 'International', 'Mediterranean', 'European', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['Asian', 'Indonesian', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['Japanese', 'Asian', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#  "['Dutch', 'Seafood', 'Fast Food']",
#  "['American', 'Bar', 'European', 'Vegetarian Friendly', 'Gluten Free Options']",
# ...

# %%
lista_comidas = ['Mediterranean', 'Contemporary', 'Asian', 'Fast Food', 'Healthy', 'Vegetarian', 'Indian', 'Argentinean', 'Seafood', 'Chienese', 'Italian', 'Grill', 'Sushi', 'Vegan', 'Mexican']

# %%
tipo = 'Asian'

# %%
precio = 'medium'

# %%
ciudad = 'Amsterdam'

# %%
gluten_free = 'Yes'

# %%
df_restaurants['Cuisine Style']
# Out:
# 0                          ['French', 'Dutch', 'European']
# 1        ['Dutch', 'European', 'Vegetarian Friendly', '...
# 2        ['Mediterranean', 'French', 'International', '...
# 3        ['French', 'European', 'International', 'Conte...
# 4        ['Dutch', 'European', 'International', 'Vegeta...
#                                ...
# 75424    ['Chinese', 'Swiss', 'Mediterranean', 'European']
# 75425                  ['Italian', 'African', 'Ethiopian']
# 75426                   ['Italian', 'Vegetarian Friendly']
# 75427    ['International', 'European', 'Contemporary', ...
# 75428    ['German', 'Belgian', 'Mediterranean', 'Europe...
# Name: Cuisine Style, Length: 75429, dtype: object

# %%
if 'Mediterranean' in df_restaurants['Cuisine Style']:
    df_restaurants[df_restaurants['Cuisine Style'== 'Mediterranean']]

# %%
if 'French' in list(df_restaurants['Cuisine Style'])[0]:
    print(True)
# Out:
# True

# %%
for x in list(df_restaurants['Cuisine Style']):
              if 'Mediterranean' in x:
                    df_restaurants[df_restaurants['Cuisine Style'== x]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-57e5b1ca4c36> in <module>
# ...

# %%
for x in list(df_restaurants['Cuisine Style']):
    for i in x:
# Out:
#   File "<ipython-input-87-1443a0f6d1b1>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import os
import dotenv
from pymongo import MongoClient
dotenv.load_dotenv()

client = MongoClient('mongodb://localhost/project_final')
db = client.get_database()
collection = db.get_collection("restaurants_final1")

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('5fd792c1ff18b1c014ea5731'),
#   'Name': 'Blue Pepper Restaurant And Candlelight Cruises',
#   'City': 'Amsterdam',
#   'Cuisine Style': "['Asian', 'Indonesian', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#   'Ranking': 8.0,
#   'Rating': 4.5,
#   'Price Range': 'high',
#   'Reviews': "[['Great Experience', 'A true delight'], ['01/08/2018', '01/07/2018']]",
#   'web_restaurant': 'https://www.tripadvisor.es/Restaurant_Review-g188590-d697058-Reviews-Blue_Pepper_Restaurant_And_Candlelight_Cruises-Amsterdam_North_Holland_Province.html'},
#  {'_id': ObjectId('5fd792c1ff18b1c014ea5732'),
#   'Name': 'Teppanyaki Restaurant Sazanka',
#   'City': 'Amsterdam',
#   'Cuisine Style': "['Japanese', 'Asian', 'Vegetarian Friendly', 'Vegan Options', 'Gluten Free Options']",
#   'Ranking': 9.0,
#   'Rating': 4.5,
#   'Price Range': 'high',
#   'Reviews': "[['Great Food & Service!', 'Superior food and exciting setting around...'], ['12/30/2017', '12/29/2017']]",
# ...

# %%
x = list(collection.find({"Cuisine Style": {"$regex": ".*Vegetarian.*"}, 'Price Range': precio, 'City': ciudad}, {"Name": 1, 'Rating':1, "_id": 0}))

# %%
df = pd.DataFrame(x)

# %%
df.head()
# Out:
#                        Name  Rating
# 0            The Happy Bull     4.5
# 1                   Gartine     4.5
# 2  Greenwoods Keizersgracht     4.5
# 3         Sherpa Restaurant     4.5
# 4   La Maschera Lillotatini     4.5

# %%
plt.figure(figsize=(10,7), dpi =100)
plot = sns.countplot(df_restaurants['City'], order=df_restaurants['City'].value_counts().index)
plot.set_xticklabels(plot.get_xticklabels(), rotation = 45)
plt.tight_layout()
# Out:
# /home/jose/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x = list()
y = list()
for city in list(df_restaurants['City'].unique()):
    x.append(city)
    y.append(df_restaurants[df_restaurants['City'] == city]['Rating'].mean())
fig, ax = plt.subplots(1,1,figsize=(17,7))
ax.bar(x,y,color = 'cyan',edgecolor = 'black')
ax.set_ylim(bottom=3.5)
ax.set_xticklabels(labels = x, rotation = 45)
ax.set_xlabel('City')
ax.set_ylabel('Average Review Rating')
# Out:
# <ipython-input-106-65fcbbc15e4d>:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels = x, rotation = 45)
# Text(0, 0.5, 'Average Review Rating')

# %%
lst = list(collection.find({'Price Range': 'low', 'City': 'Amsterdam'}, {"Name": 1, 'web_restaurant': 1, 'Rating':1, "_id": 0}))
df = pd.DataFrame(lst)
df.loc[0:4].web_restaurant
# Out:
# 0    https://www.tripadvisor.es/Restaurant_Review-g...
# 1    https://www.tripadvisor.es/Restaurant_Review-g...
# 2    https://www.tripadvisor.es/Restaurant_Review-g...
# 3    https://www.tripadvisor.es/Restaurant_Review-g...
# 4    https://www.tripadvisor.es/Restaurant_Review-g...
# Name: web_restaurant, dtype: object

# %%
df_.web_restaurant
# Out:
# 0    https://www.tripadvisor.es/Restaurant_Review-g...
# 1    https://www.tripadvisor.es/Restaurant_Review-g...
# 2    https://www.tripadvisor.es/Restaurant_Review-g...
# 3    https://www.tripadvisor.es/Restaurant_Review-g...
# 4    https://www.tripadvisor.es/Restaurant_Review-g...
# Name: web_restaurant, dtype: object

# %%
list(df_.web_restaurant)
# Out:
# ['https://www.tripadvisor.es/Restaurant_Review-g188590-d1955652-Reviews-Rob_Wigboldus_Vishandel-Amsterdam_North_Holland_Province.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g188590-d8562698-Reviews-Omelegg_City_Centre-Amsterdam_North_Holland_Province.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g188590-d4177229-Reviews-Omelegg_De_Pijp-Amsterdam_North_Holland_Province.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g188590-d3626201-Reviews-Frens_Haringhandel-Amsterdam_North_Holland_Province.html',
#  'https://www.tripadvisor.es/Restaurant_Review-g188590-d7285568-Reviews-Ivy_Bros-Amsterdam_North_Holland_Province.html']

# %%
for i in range(0,5):
    url = df_.web_restaurant[i]
    if st.button(f'{df_.Name}'):
        webbrowser.open_new_tab(url)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-0947599e9838> in <module>
#       1 url = ''
#       2 for i in list(df_.web_restaurant):
# ----> 3     url.append(i)
#       4
#
# AttributeError: 'str' object has no attribute 'append'
