# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %%
enlace = 'https://api.foursquare.com/v2/venues/explore'

Amsterdam = {'type': 'Point', 'coordinates': [40.4165, -3.70256]}
40.4165, -3.70256
# Out:
# (40.4165, -3.70256)

# %%
parametros = { "client_id" : 'FZIHR1CHDGDLTKY4INZF4ZWBI53251FK55IDGHGTKZX03RX4',
          "client_secret" : 'XDAHA1GTQJLEJNGQGOH5B2MRZRCEUREZEFBBOGX0PXOSM1FD',
          "v" : "20180323",
            "ll":f"{Amsterdam.get('coordinates')[0]},{Amsterdam.get('coordinates')[1]}",
          "query": "bar",
          "limit" : 100
}

# %%
resp = requests.get (url = enlace, params = parametros)
data = json.loads(resp.text)

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5fd732dacd8c3838dbd33796'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 600,
#   'headerLocation': 'Sol',
#   'headerFullLocation': 'Sol, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'bar',
#   'totalResults': 353,
#   'suggestedBounds': {'ne': {'lat': 40.42793283212066,
#     'lng': -3.6947075967962046},
#    'sw': {'lat': 40.405442347678814, 'lng': -3.71559387155604}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc7603c6501c9b61e4f3e29',
#        'name': 'Yambala',
#        'contact': {},
#        'location': {'address': 'C. Coloreros',
#         'lat': 40.41664556425945,
# ...

# %%
decoding_data = data.get("response")

# %%
decoded = decoding_data.get("groups")[0]

# %%
restaurantes = decoded.get("items")

# %%
restaurantes
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bc7603c6501c9b61e4f3e29',
#    'name': 'Yambala',
#    'contact': {},
#    'location': {'address': 'C. Coloreros',
#     'lat': 40.41664556425945,
#     'lng': -3.7070215912078375,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.41664556425945,
#       'lng': -3.7070215912078375}],
#     'distance': 378,
#     'postalCode': '28013',
#     'cc': 'ES',
#     'city': 'Madrid',
#     'state': 'Madrid',
#     'country': 'España',
#     'formattedAddress': ['C. Coloreros', '28013 Madrid Madrid', 'España']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'verified': False,
# ...

# %%
from functools import reduce
import operator

# %%
mapa_nombre = ["venue","name"]
latitud = ["venue", "location","lat"]
longitud = ["venue","location","lng"]

# %%
def getFromDict(diccionario,mapa):
    return reduce(operator.getitem,mapa,diccionario)

# %%
lovemosclaro = []
for diccionario in restaurantes:
    paralista = {}
    paralista["name"] = getFromDict(diccionario,mapa_nombre)
    paralista["latitud"] = getFromDict(diccionario,latitud)
    paralista["longitud"] = getFromDict(diccionario,longitud)
    lovemosclaro.append(paralista)

# %%
dataframefinal = pd.DataFrame(lovemosclaro)
dataframefinal.head()
# Out:
#                  name    latitud  longitud
# 0             Yambala  40.416646 -3.707022
# 1       El Imperfecto  40.413700 -3.699781
# 2   El Sur De Huertas  40.413719 -3.699394
# 3     Cerveceria Erte  40.419241 -3.707470
# 4  El Rincón del Cabo  40.411716 -3.703075

# %%
dataframefinal[dataframefinal.name=='Ates']
# Out:
# Empty DataFrame
# Columns: [name, latitud, longitud]
# Index: []

# %%
dataframefinal.to_csv('../data/dataframefinal.csv')
